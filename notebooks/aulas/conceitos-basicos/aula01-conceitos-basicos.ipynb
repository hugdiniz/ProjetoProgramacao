# %% [markdown]
# <br>
#
# # Conceitos Básicos
#
# <h4></h4>
# <h5  class="alert alert-warning" role="alert">Atenção: Sempre executar a célula abaixo, antes de qualquer outra.</h5>

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display, Markdown, Latex,HTML
from urllib.request import urlopen

import pandas as pd
pd.options.display.max_columns = None
import numpy as np
from dateutil.parser import parse
# Out:
# <style>
# h1, h2, h3, h4, h5, h6 {
#     color: #222;
#     font-weight: 600;
#     line-height: 1.3;
# }
#
# h2 {
#     margin-top: 1.3em;
# }
#
# a {
#     color: #0083e8;
# }
#
# .list{
#     color: black !important;
#     font-size: 20px;
# }
#
# .title{
#     color: black !important;
#     font-size: 15px;
#     font-weight: 500;
# }
#
# .value{
#     color: black !important;
#     font-size: 14px;
#
# }
#
# .alerta{
#     text-align: center;
#     color: #5c4030 !important;
#     font-weight: 500;
#
# }</style>
# <style src='https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css'></style>
# <script src='https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js'></script>

# %% [markdown]
# ## Instruções primarias:

# %% [markdown]
# ###  Soma, Subtração, Divisão, Multiplicação e módulo da divisão.

# %%
1 + 1
# Out:
# 2

# %%
1 - 1
# Out:
# 0

# %%
2 * 2
# Out:
# 4

# %%
2 / 2
# Out:
# 1.0

# %%
5 % 3
# Out:
# 2

# %% [markdown]
# ### Variáveis.

# %%
variavel = 10
variavel + 1
# Out:
# 11

# %%
variavel = variavel + 1
variavel + 1
# Out:
# 12

# %% [markdown]
# <div class="alert alert-secondary" role="alert">
#   <h4 class="alert-heading">Tipos primitivos:</h4>
#   <p>O tipo é uma forma de classificar as informação. As linguagens de programação normalmente trazem implementado o que é chamado de tipos primitivos, isto é, o tipo de dado mais genérico possível.<br>
# Toda informação que manipularemos será, por definição, de um tipo.</p>
#   <hr>
#   <h4 class="alert-heading">Os Tipos primitivos são:</h4>
#     <ul class="list-group">
#       <li class="list-group-item">Int(Numero Inteiro)</li>
#       <li class="list-group-item">Float(Numero Real)</li>
#       <li class="list-group-item">Boolean(Verdadeiro ou Falso)</li>
#       <li class="list-group-item">String (Texto)</li>
#       <li class="list-group-item">Char(Caracter)</li>
#     </ul>
# </div>

# %% [markdown]
# ### Instrução de Comparação
# #### Igual

# %%
1 == 1
# Out:
# True

# %% [markdown]
# #### Diferente

# %%
1 == 2
# Out:
# False

# %% [markdown]
# #### Maior que e Menor que

# %%
1 < 2
# Out:
# True

# %%
1 > 2
# Out:
# False

# %% [markdown]
# #### Maior ou igual que e Menor ou igual que

# %%
1 <= 2
# Out:
# True

# %%
1 >= 2
# Out:
# False

# %% [markdown]
# #### AND (E)

# %%
1 == 1 and False
# Out:
# False

# %%
1 == 1 and True
# Out:
# True

# %% [markdown]
# #### OR (ou)

# %%
1 == 1 or False
# Out:
# True

# %%
1 == 2 or False
# Out:
# False

# %% [markdown]
# ## Controle de Fluxo

# %% [markdown]
# ### IF -- Se

# %%
if(1 == 1):
    print("Verdadeiro")
# Out:
# Verdadeiro

# %% [markdown]
# ### else -- Senão

# %%
if(1 == 2):
    print("Verdadeiro")
else:
    print("Falso")
# Out:
# Falso

# %% [markdown]
# ## else if(elif) -- senão se

# %%
if(1 == 2):
    print("Verdadeiro")
elif(1 == 1):
    print("Senão se")
else:
    print("Falso")
# Out:
# Senão se

# %% [markdown]
# # Exercícios

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 1:</h4>
#   <p>A partir de uma variável x, verificar se um numero inteiro qualquer entre 1 e 4 é primo</p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 2:</h4>
#   <p>A partir de uma variável x, verificar se ela é impar ou par, se for impar, imprimir "Impar", se for par imprimir "Par".</p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 3:</h4>
#   <p>Seja 3 variáveis, dia, mês e ano, verificar se a data foi escrita de forma correta, se for correta imprima "Data Correta" senão "Data Incorreta"</p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 4:</h4>
#   <p>Leia o horário (0–23) e diga se é manhã (0–11), tarde (12–17) ou noite (18–23)."</p>
# </div>

# %%
horario = 2
if(horario >= 0 and horario <= 11):
  print("manha")
elif(horario > 11 and horario <= 17):
  print("tarde")
else:
  print("noite")
# Out:
# manha

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 5:</h4>
#   <p>Peça o nome de um dia da semana e diga se é dia útil ou fim de semana.."</p>
# </div>

# %%
dia = "cachorro quente"
if(dia == "segunda"or dia == "terca" or dia == "quarta" or dia == "quinta" or dia == "sexta"):
  print ("dia util")
else:
  print ("fim de semana")
# Out:
# fim de semana

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 6:</h4>
#   <p>Peça o nome de um dia da semana e diga se é dia útil ou fim de semana.."</p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 7:</h4>
#   <p>Leia dois números, a variavel A e variavel B e exiba o maior deles e indique qual é a variavel, se a A ou a B"</p>
# </div>

# %%
A = 8
B = 66
if(A>B):
  print("variável A é maior")
  print(A)
else:
  print("variável B é maior")
  print(B)
# Out:
# variável B é maior
# 66

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 7:</h4>
#   <p>Leia o valor de uma compra e aplique descontos:
#
# acima de 500 → 20%
#
# entre 200 e 500 → 10%
#
# entre 100 e 199 → 5%
#
# abaixo de 100 → sem desconto
# Mostre o valor final."</p>
# </div>

# %%
compra = 680
if(compra < 100):
  print("sem desconto")
elif (compra >= 100 and compra < 199):
  print("desconto 5%")
  print(compra - (compra*0.05))
elif(compra >= 200 and compra < 500):
  print("desconto 10%")
  print(compra - (compra*0.1))
elif(compra >= 500):
  print("desconto 20%")
  print(compra - (compra*0.2))
# Out:
# desconto 20%
# 544.0

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 8:</h4>
# </div>
#
# Peça ao usuário seu consumo mensal (kWh) e classifique:
#
# - até 150 → Tarifa Verde
#
# - 151–300 → Tarifa Azul
#
# - 301–500 → Tarifa Amarela
#
# - acima de 500 → Tarifa Vermelha
#
# Mostre também quantos kWh ultrapassaram a faixa anterior.

# %%
kWh =800
if(kWh <= 150):
  print("tarifa verde")
elif(kWh >= 151 and kWh <= 300):
  print("tarifa azul")
  print(str(kWh-150) + " ultrapassou")
elif(kWh >= 301 and kWh <= 500):
  print("tarifa amarela")
  print(str(kWh-301)  + " ultrapassou")
elif(kWh > 500):
  print("tarifa vermelha")
  print(str(kWh-500)  + " ultrapassou")
# Out:
# tarifa vermelha
# 300 ultrapassou

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 9:</h4>
# </div>
#
# Verificar Aprovação com Média e Frequência
#
# Leia a média final de um aluno e sua frequência (%).
# O aluno é aprovado se:
# - média ≥ 6 e frequência ≥ 75%.
# - Caso contrário, dizer se ele está:
# - reprovado por nota,
# - reprovado por frequência,
# - ou por ambos.

# %%
media = 2
frequencia = 40
if(media >= 6 and frequencia >= 75):
  print("aluno aprovado")
elif(media<6 and frequencia <75):
  print("reprovado por nota e frequencia")
  print(str(media-6) + " faltou para a aprovacao")
  print(str(frequencia-75) + " faltou para a aprovacao")
elif(media < 6):
  print("reprovado por nota")
  print(str(media-6) + " faltou para a aprovacao")
elif(frequencia < 75):
  print("reprovado por frequencia")
  print(str(frequencia-75) + " faltou para a aprovacao")
# Out:
# reprovado por nota e frequencia
# -4 faltou para a aprovacao
# -35 faltou para a aprovacao

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 10:</h4>
# </div>
#
#
# Leia as notas p1, p2, p3 e op, calcule a  média final de um aluno além disso avalie sua frequência (%).
# O aluno é aprovado se:
# - média da p1 e p2 ≥ 6 e frequência ≥ 75%.
# - media da p1 e op ou p2 e op é maior ou igual 5

# %%
p1 = 5
p2 = 2
op = 5
frequencia = 75
media = (p1 + p2) / 2

if((p1+p2)/2 >= 6 and frequencia >= 75):
  print("aluno aprovado")
  print((p1+p2)/2)
elif(frequencia < 75):
  print("reprovado por frequencia")
elif((p1+op)/2 >= 5):
  print("aluno aprovado na optativa")
  print((p1+op)/2)
elif((op+p2)/2 >= 5):
  print("aluno aprovado na optativa")
  print((p1+op)/2)
else:
  print("reprovado")
  print((p1+op)/2)
# Out:
# aluno aprovado na optativa
# 5.0

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercicio Pŕatico 11:</h4>
# </div>
#
#
# Leia as notas p1, p2, p3 e op, calcule a  média ponderada final de um aluno.
# O aluno é aprovado se:
# - média da p1 e p2 ≥ 6 e frequência ≥ 75%.
# - media da p1, p2 e op é maior ou igual 5
#
# sendo a peso das provas:
# peso_p1 = 7
# peso_p2 = 3
# peso_op = 5

# %%
p1 = 2
p2 = 2
op = 2
frequencia = 75
media = (p1 + p2) / 2

if((((p1*7)+(p2*3))/10 >= 6) and frequencia >= 75):
  print("aprovado")
  print(((p1*7)+(p2*3))/10)
elif(frequencia < 75):
  print("reprovado por frequencia")
elif(((p1*7)+(op*5))/12 >= 5):
  print("aprovado na op 1")
  print(((p1*7)+(op*5))/12 >= 5)
elif(((op*5)+(p2*3))/8 >= 5):
  print("aprovado na op")
  print(((op*5)+(p2*3))/8 >= 5)
else:
  print("reprovado por nota")
  if ():
    print()
  print(((op*5)+(p2*3))/8)
  print(((p1*7)+(op*5))/12)
# Out:
# reprovado por nota
# 2.0
# 2.0

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercício Prático 12:</h4>
#   <p>
#     Leia as notas N1, N2 e N3 de um aluno. Calcule a média ponderada:<br>
#     média = (N1 * 2 + N2 * 3 + N3 * 5) / 10.<br>
#     <br>
#     Depois:<br>
#     • Se a média for menor que 4, diminua a média em 10% (penalidade).<br>
#     • Se a média estiver entre 4 e 6, aumente a média em 5% (bônus).<br>
#     • Se a média for maior ou igual a 6, mantenha como está.<br><br>
#     Armazene o resultado em <b>media_final</b> e informe se o aluno está aprovado, em recuperação ou reprovado.
#   </p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercício Prático 13:</h4>
#   <p>
#     Receba o valor base de uma conta de água e o total de litros consumidos.<br><br>
#     • Se o consumo for maior que 20.000 L, calcule:<br>
#     excesso = consumo - 20000<br>
#     taxa = excesso * 0,002<br><br>
#     • Se o consumo for acima de 30.000 L, multiplique a taxa por 1.5.<br>
#     • Caso contrário, taxa = 0.<br><br>
#     Calcule a variável <b>conta_final</b> = base + taxa e exiba também o excesso quando existir.
#   </p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercício Prático 14:</h4>
#   <p>
#     Leia a velocidade atual de um veículo e a velocidade permitida.<br>
#     Calcule:<br>
#     dif = velocidade_atual - velocidade_permitida<br><br>
#     Depois aplique a multa:<br>
#     • Se dif ≤ 0 → sem multa.<br>
#     • Se dif &lt; 20 → multa = dif * 5<br>
#     • Se 20 ≤ dif ≤ 40 → multa = dif * 8 e depois multa = multa * 1.1<br>
#     • Se dif &gt; 40 → multa = dif * 12 e depois multa = multa * 1.25<br><br>
#     Armazene o valor em <b>multa_final</b> e exiba o resultado.
#   </p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercício Prático 15:</h4>
#   <p>
#     Leia o salário bruto de um funcionário e calcule o salário líquido de acordo com as seguintes regras:<br><br>
#     • Calcule a variável <b>inss</b> como 9% do salário bruto.<br>
#     • Calcule a variável <b>ir</b>:<br>
#     &nbsp;&nbsp;– Se o salário bruto for menor que 2500, ir = 0.<br>
#     &nbsp;&nbsp;– Se estiver entre 2500 e 4000, ir = salário_bruto * 0.07.<br>
#     &nbsp;&nbsp;– Se for maior que 4000, ir = salário_bruto * 0.12.<br><br>
#     Em seguida, calcule:<br>
#     salário_liquido = salário_bruto - inss - ir<br><br>
#     Exiba o salário líquido e os descontos aplicados.
#   </p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercício Prático 16:</h4>
#   <p>
#     Leia a distância percorrida (em km) e o tempo gasto (em horas) por um veículo.<br>
#     Calcule a velocidade média:<br>
#     velocidade_media = distancia / tempo<br><br>
#     Então classifique:<br>
#     • velocidade_media &lt; 40 → "Muito lento"<br>
#     • 40 ≤ velocidade_media &lt; 80 → "Velocidade normal"<br>
#     • 80 ≤ velocidade_media &lt; 120 → "Rápido"<br>
#     • velocidade_media ≥ 120 → "Muito rápido"<br><br>
#     Exiba a velocidade média calculada e a classificação.
#   </p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading">Exercício Prático 17:</h4>
#   <p>
#     Um produto possui um preço inicial. Leia também a categoria dele (1, 2 ou 3).<br><br>
#     • Se categoria = 1, aumente o preço em 5%.<br>
#     • Se categoria = 2, aumente o preço em 10%.<br>
#     • Se categoria = 3, aumente o preço em 15%.<br><br>
#     Depois, verifique o preço final:<br>
#     • Se preço_final &gt; 1000, aplique um desconto adicional de 8%.<br>
#     • Caso contrário, aplique um desconto de 3%.<br><br>
#     Armazene tudo na variável <b>preco_final</b> e exiba o resultado final do produto.
#   </p>
# </div>
